# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

import torch
import torchvision
from torchvision import transforms

import os
import matplotlib.pyplot as plt

import glob

files = glob.glob(os.getcwd() + '/result_img/*')
for file in files:
    print(file)
# Out:
# /Users/motacapla/Coding/Web/Tutter/api/fish_detector/result_img/1_4_result.jpg
# /Users/motacapla/Coding/Web/Tutter/api/fish_detector/result_img/1_9_result.jpg
# /Users/motacapla/Coding/Web/Tutter/api/fish_detector/result_img/1_10_result.jpg
# /Users/motacapla/Coding/Web/Tutter/api/fish_detector/result_img/1_1_result.jpg
# /Users/motacapla/Coding/Web/Tutter/api/fish_detector/result_img/1_6_result.jpg
# /Users/motacapla/Coding/Web/Tutter/api/fish_detector/result_img/1_12_result.jpg
# /Users/motacapla/Coding/Web/Tutter/api/fish_detector/result_img/1_3_result.jpg
# /Users/motacapla/Coding/Web/Tutter/api/fish_detector/result_img/1_5_result.jpg
# /Users/motacapla/Coding/Web/Tutter/api/fish_detector/result_img/1_8_result.jpg
# /Users/motacapla/Coding/Web/Tutter/api/fish_detector/result_img/1_11_result.jpg
# /Users/motacapla/Coding/Web/Tutter/api/fish_detector/result_img/1_2_result.jpg
# /Users/motacapla/Coding/Web/Tutter/api/fish_detector/result_img/1_7_result.jpg

# %%
for file in files:
    img = cv2.imread(file)
    im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(im_rgb)
    plt.show()
